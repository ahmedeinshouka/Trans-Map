# %% [markdown]
# ## OSRM (Open Source Routing Machine)
#
# **Author**: SADDIK Imad
# <br/>
# **Date**: 26/12/2024
#
# ---

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Nearest service](#toc1_)
#   - [Setup](#toc1_1_)
#   - [Using the service](#toc1_2_)
#     - [General options](#toc1_2_1_)
#     - [Making the request](#toc1_2_2_)
#     - [Another example](#toc1_2_3_)

# %% [markdown]
# ---

# %% [markdown]
# # <a id='toc1_'></a>[Nearest service](#toc0_)

# %% [markdown]
# Use this service if you want to snap a coordinate to the street network. Read more about it [here](https://project-osrm.org/docs/v5.24.0/api/#nearest-service).

# %% [markdown]
# ## <a id='toc1_1_'></a>[Setup](#toc0_)

# %% [markdown]
# I selected one point from the map and I will visualize it with the `Folium` package.

# %%
import folium

from folium import Map
from pydantic import BaseModel


class Point(BaseModel):
    latitude: float
    longitude: float


def get_folium_map(center_point: Point, points: list[Point], zoom_level: int = 14) -> Map:
    folium_map = folium.Map(
        location=[center_point.latitude, center_point.longitude], zoom_start=zoom_level)

    for point in points:
        folium.Marker(location=[point.latitude, point.longitude],
                      popup='Point').add_to(folium_map)

    return folium_map


point_1 = Point(latitude=33.89264295626195, longitude=-5.500305816538693)
center_point = Point(latitude=33.89264295626195, longitude=-5.500305816538693)

folium_map = get_folium_map(center_point, [point_1], zoom_level=18)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c21577e49e2bb489945c60a27eeed97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c21577e49e2bb489945c60a27eeed97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c21577e49e2bb489945c60a27eeed97 = L.map(
#                 &quot;map_8c21577e49e2bb489945c60a27eeed97&quot;,
#                 {
#                     center: [33.89264295626195, -5.500305816538693],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3298b7b630e94c327b0e8556f1b75a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c21577e49e2bb489945c60a27eeed97);
#
#
#             var marker_a8aa4e2ccff67be40022ed61570e2bed = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_8c21577e49e2bb489945c60a27eeed97);
#
#
#         var popup_21f085133a1434adc8b4e0f392943cc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2df572864095b2b016b5be42616da31 = $(`&lt;div id=&quot;html_f2df572864095b2b016b5be42616da31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_21f085133a1434adc8b4e0f392943cc8.setContent(html_f2df572864095b2b016b5be42616da31);
#
#
#
#         marker_a8aa4e2ccff67be40022ed61570e2bed.bindPopup(popup_21f085133a1434adc8b4e0f392943cc8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <a id='toc1_2_'></a>[Using the service](#toc0_)

# %% [markdown]
# ### <a id='toc1_2_1_'></a>[General options](#toc0_)

# %% [markdown]
# The general options are used in every OSRM service, read more about them [here](https://project-osrm.org/docs/v5.5.1/api/?language=cURL#general-options). Here is a table that summarizes the options with their description.
#
#
# | Parameter | Description |
# |-----------|-------------|
# | service | One of the following values: `route`, `nearest`, `table`, `match`, `trip`, `tile` |
# | version | Version of the protocol implemented by the service. `v1` for all OSRM 5.x installations |
# | profile | Mode of transportation, is determined statically by the Lua profile that is used to prepare the data using `osrm-extract`. Typically `car`, `bike` or `foot` if using one of the supplied profiles. |
# | coordinates | String of format `{longitude},{latitude};{longitude},{latitude};{longitude},{latitude} ...]` or `polyline({polyline})`. |
# | format | Only `json` is supported at the moment. This parameter is optional and defaults to `json`. |

# %% [markdown]
# ### <a id='toc1_2_2_'></a>[Making the request](#toc0_)

# %%
service = 'nearest'
version = 'v1'
profile = 'driving'
host = 'http://localhost:5000'

# %% [markdown]
# The nearest endpoint follows this format: `/nearest/v1/{profile}/{coordinates}?number={number}`.
#
# When using this service, you should use only one point when providing the coordinates parameter.

# %%
import requests

coordinates = f'{point_1.longitude},{point_1.latitude}'
number_of_snap_points = 1

url = f"{host}/{service}/{version}/{profile}/{
  
    coordinates}?number={number_of_snap_points}"

response = requests.get(url)
response.status_code
# Out:
#   Cell In[3], line 6
#     url = f"{host}/{service}/{version}/{profile}/{
#           ^
# SyntaxError: unterminated string literal (detected at line 6)

# %% [markdown]
# The `200` status code indicates that the request was successful. Next, let's retrieve the coordinates of the point snapped to the street network.

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['code', 'waypoints'])

# %%
waypoints = data['waypoints']
print(f"Number of waypoints: {len(waypoints)}")
# Out:
# Number of waypoints: 1

# %% [markdown]
# Let's extract the waypoints dynamically

# %%
nearest_points = []
for waypoint in waypoints:
    latitude = waypoint['location'][1]
    longitude = waypoint['location'][0]
    nearest_points.append(Point(latitude=latitude, longitude=longitude))

nearest_points
# Out:
# [Point(latitude=33.892547, longitude=-5.500277)]

# %% [markdown]
# When adding the waypoint to the map, it is snapped to the nearest street, even if the original point was located on a building. Why is this necessary? To calculate the shortest path between two points, the algorithm requires the points to be on the street network rather than on buildings.

# %%
folium_map = get_folium_map(center_point, [point_1], zoom_level=18)

for point in nearest_points:
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        color='blue',
                        fill=True,
                        fill_color='blue').add_to(folium_map)

folium_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 folium_map = get_folium_map(center_point, [point_1], zoom_level=18)
# ----> 3 for point in nearest_points:
#       4     folium.CircleMarker(location=[point.latitude, point.longitude],
#       5                         radius=5,
#       6                         color='blue',
#       7                         fill=True,
#       8                         fill_color='blue').add_to(folium_map)
#      10 folium_map
#
# NameError: name 'nearest_points' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### <a id='toc1_2_3_'></a>[Another example](#toc0_)

# %% [markdown]
# In this example, we will load a CSV file containing several points that are not located on the street network. We will iterate through these points and use the nearest service to find the closest points snapped to the street network for each one.

# %%
import pandas as pd

data = pd.read_csv('../data/nearest_service_data.csv')
data.head()
# Out:
#     latitude  longitude
# 0  33.892618  -5.500416
# 1  33.892538  -5.500902
# 2  33.892312  -5.501063
# 3  33.891908  -5.501253
# 4  33.891870  -5.501506

# %%
points = []
for _, row in data.iterrows():
    point = Point(latitude=row['latitude'], longitude=row['longitude'])
    points.append(point)

points[:5]
# Out:
# [Point(latitude=33.89261795639958, longitude=-5.500416069831112),
#  Point(latitude=33.89253843494372, longitude=-5.500902451816623),
#  Point(latitude=33.8923118737899, longitude=-5.501062653942593),
#  Point(latitude=33.891908002407774, longitude=-5.501252523134825),
#  Point(latitude=33.89186983153817, longitude=-5.501506176515667)]

# %% [markdown]
# Here are the locations of all the points displayed on the map.

# %%
folium_map = get_folium_map(points[5], points, zoom_level=18)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_202f4ab35d6254ddb6cd7a3bc2026d38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_202f4ab35d6254ddb6cd7a3bc2026d38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_202f4ab35d6254ddb6cd7a3bc2026d38 = L.map(
#                 &quot;map_202f4ab35d6254ddb6cd7a3bc2026d38&quot;,
#                 {
#                     center: [33.89189938318031, -5.5018770147702245],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52ed0be085e47526c2882aa679226be9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_52ed0be085e47526c2882aa679226be9.addTo(map_202f4ab35d6254ddb6cd7a3bc2026d38);
#
#
#             var marker_166365fe25d6ae78bf64606b838a524a = L.marker(
#                 [33.89261795639958, -5.500416069831112],
#                 {}
#             ).addTo(map_202f4ab35d6254ddb6cd7a3bc2026d38);
#
#
#         var popup_0bb3047b5e79b5f3f592131ace3ad7ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e146bb7f84791e6756aa0281055141e5 = $(`&lt;div id=&quot;html_e146bb7f84791e6756aa0281055141e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_0bb3047b5e79b5f3f592131ace3ad7ce.setContent(html_e146bb7f84791e6756aa0281055141e5);
#
#
#
#         marker_166365fe25d6ae78bf64606b838a524a.bindPopup(popup_0bb3047b5e79b5f3f592131ace3ad7ce)
#         ;
#
#
#
#
#             var marker_e111bd20fdbfae5fca7ee09f2fa9088c = L.marker(
#                 [33.89253843494372, -5.500902451816623],
#                 {}
#             ).addTo(map_202f4ab35d6254ddb6cd7a3bc2026d38);
#
#
#         var popup_456881709df85e3e8d7aba484caf5f31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_112ddc2097b76c9ba064a3291be87fcc = $(`&lt;div id=&quot;html_112ddc2097b76c9ba064a3291be87fcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_456881709df85e3e8d7aba484caf5f31.setContent(html_112ddc2097b76c9ba064a3291be87fcc);
#
#
#
#         marker_e111bd20fdbfae5fca7ee09f2fa9088c.bindPopup(popup_456881709df85e3e8d7aba484caf5f31)
#         ;
#
#
#
#
#             var marker_5ae0fa75e98a885e41e01a1f718675a4 = L.marker(
#                 [33.8923118737899, -5.501062653942593],
#                 {}
#             ).addTo(map_202f4ab35d6254ddb6cd7a3bc2026d38);
#
#
#         var popup_5d22031231ac0e61f74f9cd6001e3055 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42c5eb6d8f4f18354a99485d0acb5e56 = $(`&lt;div id=&quot;html_42c5eb6d8f4f18354a99485d0acb5e56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_5d22031231ac0e61f74f9cd6001e3055.setContent(html_42c5eb6d8f4f18354a99485d0acb5e56);
#
#
#
#         marker_5ae0fa75e98a885e41e01a1f718675a4.bindPopup(popup_5d22031231ac0e61f74f9cd6001e3055)
#         ;
#
#
#
#
#             var marker_ce4e0448cf1679ba140477f2fa8ccb8f = L.marker(
#                 [33.891908002407774, -5.501252523134825],
#                 {}
#             ).addTo(map_202f4ab35d6254ddb6cd7a3bc2026d38);
#
#
#         var popup_847ef3a85ddc15ee8932841482956329 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_932abe508cfc159ec445a2c0bf7a0268 = $(`&lt;div id=&quot;html_932abe508cfc159ec445a2c0bf7a0268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_847ef3a85ddc15ee8932841482956329.setContent(html_932abe508cfc159ec445a2c0bf7a0268);
#
#
#
#         marker_ce4e0448cf1679ba140477f2fa8ccb8f.bindPopup(popup_847ef3a85ddc15ee8932841482956329)
#         ;
#
#
#
#
#             var marker_511f6abade730ca0bcfb163ca72b53ab = L.marker(
#                 [33.89186983153817, -5.501506176515667],
#                 {}
#             ).addTo(map_202f4ab35d6254ddb6cd7a3bc2026d38);
#
#
#         var popup_f7d5471de22ae5e93cb6aaec55c09e22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6046f1b7e8a7011fca1efa848aef9d5f = $(`&lt;div id=&quot;html_6046f1b7e8a7011fca1efa848aef9d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_f7d5471de22ae5e93cb6aaec55c09e22.setContent(html_6046f1b7e8a7011fca1efa848aef9d5f);
#
#
#
#         marker_511f6abade730ca0bcfb163ca72b53ab.bindPopup(popup_f7d5471de22ae5e93cb6aaec55c09e22)
#         ;
#
#
#
#
#             var marker_4fae672de1015faa5fc3989243fcc44b = L.marker(
#                 [33.89189938318031, -5.501877014770224

# %%
def get_waypoints(point: Point) -> list[Point]:
    coordinates = f'{point.longitude},{point.latitude}'
    number_of_snap_points = 1

    url = f"{
        host}/{service}/{version}/{profile}/{coordinates}?number={number_of_snap_points}"

    response = requests.get(url)

    data = response.json()
    waypoints = [Point(latitude=point['location'][1], longitude=point['location'][0])
                 for point in data['waypoints']]

    return waypoints


waypoints = []
for point in points:
    waypoints.append(get_waypoints(point))

waypoints[:5]
# Out:
# [[Point(latitude=33.892523, longitude=-5.500383)],
#  [Point(latitude=33.892517, longitude=-5.500844)],
#  [Point(latitude=33.892356, longitude=-5.501059)],
#  [Point(latitude=33.891886, longitude=-5.501148)],
#  [Point(latitude=33.891806, longitude=-5.501512)]]

# %% [markdown]
# Using the nearest service, we observe that the black circle markers have been snapped to the street network.

# %%
folium_map = get_folium_map(points[5], points, zoom_level=18)

for waypoint in waypoints:
    for point in waypoint:
        folium.CircleMarker(
            location=[point.latitude, point.longitude],
            radius=5,
            color='black',
            fill=True,
            fill_color='black',
        ).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d600aa2aba9e37314d571d4d594988ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d600aa2aba9e37314d571d4d594988ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d600aa2aba9e37314d571d4d594988ec = L.map(
#                 &quot;map_d600aa2aba9e37314d571d4d594988ec&quot;,
#                 {
#                     center: [33.89189938318031, -5.5018770147702245],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_699b86602a4b7f50ef7a9629b34ca8d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_699b86602a4b7f50ef7a9629b34ca8d3.addTo(map_d600aa2aba9e37314d571d4d594988ec);
#
#
#             var marker_96f6b26958ae1baa3ee8a6ac83852536 = L.marker(
#                 [33.89261795639958, -5.500416069831112],
#                 {}
#             ).addTo(map_d600aa2aba9e37314d571d4d594988ec);
#
#
#         var popup_adfd9e4a1d0c6420a01c9c36f0d15d99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6887695e5f0a38157dd889d0f4c2f067 = $(`&lt;div id=&quot;html_6887695e5f0a38157dd889d0f4c2f067&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_adfd9e4a1d0c6420a01c9c36f0d15d99.setContent(html_6887695e5f0a38157dd889d0f4c2f067);
#
#
#
#         marker_96f6b26958ae1baa3ee8a6ac83852536.bindPopup(popup_adfd9e4a1d0c6420a01c9c36f0d15d99)
#         ;
#
#
#
#
#             var marker_b80310a2acdbff0b75df7f066d209208 = L.marker(
#                 [33.89253843494372, -5.500902451816623],
#                 {}
#             ).addTo(map_d600aa2aba9e37314d571d4d594988ec);
#
#
#         var popup_903976d2bd57cc9ffde3ffac6026d444 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc520428d5006d33275daf7049888e20 = $(`&lt;div id=&quot;html_bc520428d5006d33275daf7049888e20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_903976d2bd57cc9ffde3ffac6026d444.setContent(html_bc520428d5006d33275daf7049888e20);
#
#
#
#         marker_b80310a2acdbff0b75df7f066d209208.bindPopup(popup_903976d2bd57cc9ffde3ffac6026d444)
#         ;
#
#
#
#
#             var marker_c9e8f231b446a9ae5205a9e5e761dda3 = L.marker(
#                 [33.8923118737899, -5.501062653942593],
#                 {}
#             ).addTo(map_d600aa2aba9e37314d571d4d594988ec);
#
#
#         var popup_e58d6d0335355062af490626403b3719 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca9668f79488396bac3f44cbde76c747 = $(`&lt;div id=&quot;html_ca9668f79488396bac3f44cbde76c747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_e58d6d0335355062af490626403b3719.setContent(html_ca9668f79488396bac3f44cbde76c747);
#
#
#
#         marker_c9e8f231b446a9ae5205a9e5e761dda3.bindPopup(popup_e58d6d0335355062af490626403b3719)
#         ;
#
#
#
#
#             var marker_3ac1d050afa23abc3a352aa3838ba8e2 = L.marker(
#                 [33.891908002407774, -5.501252523134825],
#                 {}
#             ).addTo(map_d600aa2aba9e37314d571d4d594988ec);
#
#
#         var popup_3d235638f1e3011c6d0a298bec3b9090 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_277cef8c226bb03ef59c75452514d4d7 = $(`&lt;div id=&quot;html_277cef8c226bb03ef59c75452514d4d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_3d235638f1e3011c6d0a298bec3b9090.setContent(html_277cef8c226bb03ef59c75452514d4d7);
#
#
#
#         marker_3ac1d050afa23abc3a352aa3838ba8e2.bindPopup(popup_3d235638f1e3011c6d0a298bec3b9090)
#         ;
#
#
#
#
#             var marker_98873fde4566a4d911658d2dc7bf1530 = L.marker(
#                 [33.89186983153817, -5.501506176515667],
#                 {}
#             ).addTo(map_d600aa2aba9e37314d571d4d594988ec);
#
#
#         var popup_f5940f351b5fac252d2dfde8025b5f45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_477b343f3c2b89363d39540486643b2a = $(`&lt;div id=&quot;html_477b343f3c2b89363d39540486643b2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_f5940f351b5fac252d2dfde8025b5f45.setContent(html_477b343f3c2b89363d39540486643b2a);
#
#
#
#         marker_98873fde4566a4d911658d2dc7bf1530.bindPopup(popup_f5940f351b5fac252d2dfde8025b5f45)
#         ;
#
#
#
#
#             var marker_cd2a163796833febebe3dd92fbadf541 = L.marker(
#                 [33.89189938318031, -5.501877014770224
